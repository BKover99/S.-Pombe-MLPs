# %%
#find snps
#import data science libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import /Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/QTL mapping/permutations/results.csv
#read in data
snps = pd.read_csv('/Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/GWAS/gwas_hits.csv')
#washing phenotype /Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/QTL mapping/washing_phenotypes.csv
wash_pheno = pd.read_csv('/Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/QTL mapping/washing_phenotypes.csv')
#import rna seq corrs /Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/Analysis of Clement-Ziza RNA-seq/wash_corr.csv
wash_corr = pd.read_csv('/Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/Analysis of Clement-Ziza RNA-seq/wash_corr.csv')
#full snp dataset /Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/QTL mapping/SupplementaryDataset_S7_genotype.tsv
full_snps = pd.read_csv('/Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/QTL mapping/SupplementaryDataset_S7_genotype.tsv', sep='\t',header=15)
#load orthologs database /Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/Orthologs/final_orthology_database.csv
orthologs = pd.read_csv('/Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/Bence folder/Orthologs/final_orthology_database.csv')

# %%
#for now remove 2nd and 13th row, and reset index
snps = snps.drop([2,13])
snps = snps.reset_index(drop=True)
#create two columns for the two alleles found in alleles
snps['allele1'] = snps['alleles'].str.split(',').str[0]
snps['allele2'] = snps['alleles'].str.split(',').str[1]
#remove sorrounding ['' and ''] from alleles
snps['allele1'] = snps['allele1'].str.replace('[','')
snps['allele2'] = snps['allele2'].str.replace(']','')
#remove surrounding '' from alleles
snps['allele1'] = snps['allele1'].str.replace('\'','')
snps['allele2'] = snps['allele2'].str.replace('\'','')
#remove extra space from allele2
snps['allele2'] = snps['allele2'].str.replace(' ','')
snps
# Out:
# /var/folders/mb/vdj4y7t13zd3tzlk99b8ycd40000gn/T/ipykernel_44819/480895657.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   snps['allele1'] = snps['allele1'].str.replace('[','')
# /var/folders/mb/vdj4y7t13zd3tzlk99b8ycd40000gn/T/ipykernel_44819/480895657.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   snps['allele2'] = snps['allele2'].str.replace(']','')
#     Unnamed: 0        locus                                alleles   n  \
# 0        32612    I:3364859                             ['C', 'T']  55
# 1        34916    I:3585317                             ['A', 'C']  55
# 2       100775   II:4296875                             ['T', 'A']  55
# 3       100776   II:4296877                             ['G', 'A']  55
# 4       133051  III:2219006                             ['A', 'C']  55
# 5       133289  III:2227937                             ['T', 'G']  55
# 6       133295  III:2228740                             ['C', 'T']  55
# 7       133311  III:2230713                             ['G', 'A']  55
# 8         1011     I:498798                            ['TG', 'T']  52
# 9         1028     I:519884                            ['A', 'AT']  52
# 10        1036     I:522785                            ['A', 'AT']  52
# 11        1201     I:723772                        ['T', 'TGTCTC']  52
# 12        9218   II:1721443                           ['A', 'ACT']  52
# 13       10303   II:2693701                     ['GT', 'G', 'GTT']  52
# 14       10305   II:2693728                         ['AC', 'AACA']  52
# 15       10306   II:2694024                            ['A', 'AT']  52
# 16       10307   II:2694637                            ['G', 'GT']  52
# 17       10308   II:2697960                            ['AT', 'A']  52
# 18       15230  III:2204023                            ['TA', 'T']  52
# 19       15249  III:2218509                           ['C', 'CGA']  52
# 20       15309  III:2277085                            ['T', 'TC']  52
# 21       15327  III:2291604  ['GCTTTTCTTAACAGATGCTTTGAGGGTA', 'G']  52
# 22       15333  III:2294439                          ['G', 'GTCA']  52
# 23       15412  III:2357290              ['C', 'CTTTTGATCTGATAAT']  52
#
#         sum_x  y_transpose_x      beta  standard_error    t_stat  \
# 0    3.235294       2.112613  0.546460        0.073554  7.429402
# 1   42.000000       5.746557 -0.366654        0.057374 -6.390640
# 2    4.400000       2.394839  0.443424        0.070286  6.308884
# 3    4.400000       2.394839  0.443424        0.070286  6.308884
# 4    5.000000       2.231398  0.471360        0.069086  6.822801
# 5    6.000000       2.267975  0.558370        0.069510  8.032999
# 6    6.000000       2.267975  0.558370        0.069510  8.032999
# 7    4.000000       2.348044  0.444547        0.069142  6.429509
# 8    6.000000       2.530626  0.311554        0.072372  4.304919
# 9    7.000000       2.673649  0.349112        0.075066  4.650735
# 10   4.000000       1.777813  0.479528        0.096000  4.995075
# 11   3.000000       1.739226  0.417287        0.088883  4.694774
# 12  32.000000       4.428636 -0.285830        0.057186 -4.998236
# 13  42.000000       6.130268 -0.397447        0.076744 -5.178866
# 14  42.000000       6.130268 -0.397447        0.076744 -5.178866
# 15  42.000000       6.130268 -0.397447        0.076744 -5.178866
# 16  42.000000       6.130268 -0.397447        0.076744 -5.178866
# 17  42.000000       6.130268 -0.397447        0.076744 -5.178866
# 18   6.000000       1.846209  0.392285        0.086302  4.545506
# 19   6.117647       1.782102  0.437682        0.089806  4.873659
# 20   3.000000       1.640883  0.401600        0.092993  4.318593
# 21   3.000000       1.640883  0.401600        0.092993  4.318593
# 22   5.000000       2.327398  0.312051        0.071491  4.364909
# 23   3.000000       1.670345  0.393597        0.092129  4.272242
#
#          p_value   type                       allele1           allele2
# 0   1.620139e-09    snp                             C                 T
# 1   6.328207e-08    snp                             A                 C
# 2   8.445186e-08    snp                             T                 A
# 3   8.445186e-08    snp                             G                 A
# 4   1.374737e-08    snp                             A                 C
# 5   1.963371e-10    snp                             T                 G
# 6   1.963371e-10    snp                             C                 T
# 7   5.516623e-08    snp                             G                 A
# 8   8.916224e-05  indel                            TG                 T
# 9   2.914204e-05  indel                             A                AT
# 10  9.351192e-06  indel                             A                AT
# 11  2.522852e-05  indel                             T            TGTCTC
# 12  9.253300e-06  indel                             A               ACT
# 13  5.059658e-06  indel                            GT                 G
# 14  5.059658e-06  indel                            AC              AACA
# 15  5.059658e-06  indel                             A                AT
# 16  5.059658e-06  indel                             G                GT
# 17  5.059658e-06  indel                            AT                 A
# 18  4.106708e-05  indel                            TA                 T
# 19  1.399329e-05  indel                             C               CGA
# 20  8.534981e-05  indel                             T                TC
# 21  8.534981e-05  indel  GCTTTTCTTAACAGATGCTTTGAGGGTA                 G
# 22  7.358208e-05  indel                             G              GTCA
# 23  9.895852e-05  indel                             C  CTTTTGATCTGATAAT

# %%
#remove Unnamed: 0 column from snps
snps = snps.drop(columns=['Unnamed: 0'])
#split locus intro two columns, Chromosome and Position
snps[['chromosome','position']] = snps['locus'].str.split(':',expand=True)
#remove locus column
snps = snps.drop(columns=['locus'])

#turn snps position into int
snps['position'] = snps['position'].astype(int)

# %%
#pandas read in "/Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/external data/Pombe genome annotation.gff3"
import pandas as pd
df = pd.read_csv('/Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/external data/Pombe genome annotation.gff3', sep='\t', header=1)
#break last column into 2 at ;
df[['a','b']] = df["ID=SPAC1002.01;Name=mrx11"].str.split(';',expand=True)
#remove column ID=SPAC1002.01;Name=mrx11
df.drop(columns =["ID=SPAC1002.01;Name=mrx11"], inplace = True)
#remove ID= from column a and rename it to ID
df['ID'] = df['a'].str.replace('ID=', '')
#remove column a
df.drop(columns =['a','PomBase',".","..1"], inplace = True)
#rename b to Parent
df.rename(columns={'b':'Parent','gene':'object','I':'chromosome','1798347':"start",'1798835':"end","+":"strand"}, inplace=True)
#In parent remove anything before =
df['Parent'] = df['Parent'].str.replace('Parent=', '')
#or Name=
df['Parent'] = df['Parent'].str.replace('Name=', '')
#create an aempty column called detail
df['detail'] = ""
#split ID column at :, and if there is something after put it in detail column
df['detail'] = df['ID'].str.split(':', expand=True)[1]
#split ID column at :, and if there is something before put it in ID column
df['ID'] = df['ID'].str.split(':', expand=True)[0]

# %%
#find a subset of df, where snps[position] is +- 1000 of df[start] or df[end]. Create a result df, and say which snps were there
#suppress warnings
import warnings
warnings.filterwarnings('ignore')

result = pd.DataFrame()
for i in range(len(snps)):
    for j in range(len(df)):
        if snps['position'][i] >= df['start'][j] - 1500 and snps['position'][i] <= df['end'][j] + 1500 :
            #and if chromsome is chromosome_2 for df chromsome II etc
            if snps['chromosome'][i] == df['chromosome'][j]:
                result = result.append({'position': snps['position'][i], 'ID': df['ID'][j], 'Parent': df['Parent'][j], 'object': df['object'][j], 'chromosome': df['chromosome'][j], 'start': df['start'][j], 'end': df['end'][j], 'strand': df['strand'][j], 'detail': df['detail'][j], "beta": snps["beta"][i], "p_value": snps["p_value"][i], "type":snps["type"][i]}, ignore_index=True)
result

#if the last two characters are .1, remove them
for i in range(len(result)):
    if result['ID'][i][-2:] == ".1":
        result['ID'][i] = result['ID'][i][:-2]

# %%
#match ID with systematic name in wash_corr and add columns gene	correlation	p-value
#create np.arrays with NAs
corrs = np.array([np.nan]*len(result))
pvals = np.array([np.nan]*len(result))
genes = np.array([np.nan]*len(result), dtype=object)
for i in range(len(result)):
    for j in range(len(wash_corr)):
        if result['ID'][i] == wash_corr['systematic_names'][j]:
            corrs[i] = wash_corr['correlation'][j]
            pvals[i] = wash_corr['p-value'][j]
            genes[i] = wash_corr['gene'][j]

            


result['correlation'] = corrs
result['p_value_corr'] = pvals
result['gene'] = genes

# %%
#add to each row the unique number of positions that ID had
#add a column called unique
#remove duplicates of ID and position but keep the highest p_value

result_final = result.drop_duplicates(subset=['ID', 'position'])
#reset index
result_final = result_final.reset_index(drop=True)
unique = np.array([])
for i in range(len(result_final)):
    #get the ID
    ID = result_final['ID'][i]
    #get the number of times ID appears in result
    count = len(result_final[result_final['ID'] == ID])
    #add count to unique
    unique = np.append(unique, count)
result_final['unique'] = unique
#show SPBC290.07 in result
#gather positions for each ID, and put in a single entry as a list. Add that to the df. THen remove duplicated IDs
result_final_ = result_final.groupby('ID')['position'].apply(list).reset_index(name='positions')
result_final__ = pd.merge(result_final, result_final_, on='ID')

#remove duplicates of ID
result_final__ = result_final__.drop_duplicates(subset=['ID'])

#reset index
result_final__ = result_final__.reset_index(drop=True)


#ignore the above 
result_final__ = result.copy()

# %%
#iterate through result_final__. If ID is found in orthologs, then add the albicans_name(s)cerevisiae_name(s) to the df
from numpy import dtype

albicans_names = np.array([np.nan]*len(result_final__),dtype=object)
cerevisiae_names = np.array([np.nan]*len(result_final__),dtype=object)
for i in range(len(result_final__)):
    for j in range(len(orthologs)):
        if result_final__['ID'][i] in orthologs['pombe_name(s)'][j]:
            albicans_names[i] = orthologs['albicans_name(s)'][j]
            cerevisiae_names[i] = orthologs['cerevisiae_name(s)'][j]
#add to df
result_final__['albicans_name(s)'] = albicans_names
result_final__['cerevisiae_name(s)'] = cerevisiae_names

# %%
#iterate through positions in result_final__  and find the corresponding alleles in snps. Then add the two values in X968_allele	Y0036_allele to the df in two new columns at the start 
#add two columns to result_final__
result_final__['allele_1'] = np.nan
result_final__['allele_2'] = np.nan
for i in range(len(result_final__)):
    for j in range(len(snps)):
        if result_final__['position'][i] == snps['position'][j]:
            result_final__['allele_1'][i] = snps['allele1'][j]
            result_final__['allele_2'][i] = snps['allele2'][j]
result_final__
# Out:
#      position            ID          Parent          object chromosome  \
# 0     3364859  SPAC26A3.13c           Tf2-4            gene          I
# 1     3364859  SPAC26A3.13c    SPAC26A3.13c            mRNA          I
# 2     3364859  SPAC26A3.13c  SPAC26A3.13c.1             CDS          I
# 3     3364859  SPAC26A3.14c            None            gene          I
# 4     3364859  SPAC26A3.14c    SPAC26A3.14c            mRNA          I
# ..        ...           ...             ...             ...        ...
# 449   2357290    SPCC70.12c      SPCC70.12c            mRNA        III
# 450   2357290    SPCC70.12c    SPCC70.12c.1  five_prime_UTR        III
# 451   2357290  SPNCRNA.7727            None            gene        III
# 452   2357290  SPNCRNA.7727    SPNCRNA.7727           ncRNA        III
# 453   2357290  SPNCRNA.7727  SPNCRNA.7727.1             CDS        III
#
#        start      end strand          detail      beta       p_value   type  \
# 0    3361547  3365548      -            None  0.546460  1.620139e-09    snp
# 1    3361547  3365548      -            None  0.546460  1.620139e-09    snp
# 2    3361547  3365548      -            exon  0.546460  1.620139e-09    snp
# 3    3366317  3367205      -            None  0.546460  1.620139e-09    snp
# 4    3366317  3367205      -            None  0.546460  1.620139e-09    snp
# ..       ...      ...    ...             ...       ...           ...    ...
# 449  2354968  2356317      -            None  0.393597  9.895852e-05  indel
# 450  2355788  2356317      -  five_prime_UTR  0.393597  9.895852e-05  indel
# 451  2354421  2358979      +            None  0.393597  9.895852e-05  indel
# 452  2354421  2358979      +            None  0.393597  9.895852e-05  indel
# 453  2354421  2358979      +            exon  0.393597  9.895852e-05  indel
#
#      correlation  p_value_corr          gene albicans_name(s)  \
# 0            NaN           NaN         Tf2-4              NaN
# 1            NaN           NaN         Tf2-4              NaN
# 2            NaN           NaN         Tf2-4              NaN
# 3      -0.399422      0.001896  SPAC26A3.14c              NaN
# 4      -0.399422      0.001896  SPAC26A3.14c              NaN
# ..           ...           ...           ...              ...
# 449     0.221542      0.094658          ecl1              NaN
# 450     0.221542      0.094658          ecl1              NaN
# 451          NaN           NaN           NaN              NaN
# 452          NaN           NaN           NaN              NaN
# 453          NaN           NaN           NaN              NaN
#
#     cerevisiae_name(s) allele_1          allele_2
# 0                  NaN        C                 T
# 1                  NaN        C                 T
# 2                  NaN        C                 T
# 3                  NaN        C                 T
# 4                  NaN        C                 T
# ..                 ...      ...               ...
# 449                NaN        C  CTTTTGATCTGATAAT
# 450                NaN        C  CTTTTGATCTGATAAT
# 451                NaN        C  CTTTTGATCTGATAAT
# 452                NaN        C  CTTTTGATCTGATAAT
# 453                NaN        C  CTTTTGATCTGATAAT
#
# [454 rows x 19 columns]

# %%
import sys, re

f=open('/Users/bencekover/Library/CloudStorage/OneDrive-UniversityCollegeLondon/MSci Bahler lab/S.-Pombe-biofilm/external data/Schizosaccharomyces_pombe_all_chromosomes.fa','r')
lines=f.readlines()

hre=re.compile('>(\S+)')
lre=re.compile('^(\S+)$')

regions={}

for line in lines:
        outh = hre.search(line)
        if outh:
                id=outh.group(1)
        else:
                outl=lre.search(line)
                if(id in regions.keys()):
                        regions[id] += outl.group(1)
                else:
                        regions[id]  =outl.group(1)

# %%
#iterate through positions in result_final__ and look up the chromosome and position in regions, and find the corresponding letter +/- 5 bp in regions. Add it to a new column
result_final__['reference_seq']=np.nan
for i in range(len(result_final__)):
    for j in range(len(regions)):
        if result_final__['chromosome'][i] == list(regions.keys())[j]:
            #add | | characters left and right of tletter at position-1
            
            result_final__['reference_seq'][i] = regions[list(regions.keys())[j]][result_final__['position'][i]-4:result_final__['position'][i]-1] + ' |' + regions[list(regions.keys())[j]][result_final__['position'][i]-1] + '| ' + regions[list(regions.keys())[j]][result_final__['position'][i]:result_final__['position'][i]+3] 

#if strand is -, reverse reference_seq
for i in range(len(result_final__)):
    if result_final__['strand'][i] == '-':
        result_final__['reference_seq'][i] = result_final__['reference_seq'][i][::-1]
        #also flip the alleles
        result_final__['allele_1'][i] = result_final__['allele_1'][i][::-1]
        result_final__['allele_2'][i] = result_final__['allele_2'][i][::-1]
#also create reference_seq_ without the | | characters
result_final__['reference_seq_'] = result_final__['reference_seq'].str.replace('|', '')
result_final__['reference_seq_'] = result_final__['reference_seq_'].str.replace(' ', '')

# %%
######
# reate column, whole gene as codons
result_final__['wt_gene'] = np.nan
#iterate through result_final__ positions. If object is CDS, then look up the sequence from start to end in regions.
#add the sequence to the df
for i in range(len(result_final__)):
    
    if result_final__['object'][i] == 'CDS':
    
        start = result_final__['start'][i]
        end = result_final__['end'][i]
        chrom = result_final__['chromosome'][i]
        pos = result_final__['position'][i]
        gene = regions[chrom][start-1:end]
        if pos > start and pos < end:
        
            if result_final__['strand'][i] == '-':
                
                gene = gene[::-1]
            
                gene = ''.join(gene)
            #write the gene as triplets of letters like AAA, ATC, etc
            #if divisible by 3
            if len(gene)%3 != 0:
                gene = gene[:-(len(gene)%3)]
            gene = [gene[i:i+3] for i in range(0, len(gene), 3)]
                #only triplets near the position
            if result_final__['strand'][i] == '+':
                gene = gene[(pos-start)//3-4:(pos-end)//3+4]
            else: 
                gene = gene[(end-pos)//3-4:(start-pos)//3+4]
            
                
                


            result_final__['wt_gene'][i] = gene

result_final__['mutant allele'] = np.nan
for i in range(len(result_final__)):
    if result_final__['object'][i] == 'CDS':
    
        start = result_final__['start'][i]
        end = result_final__['end'][i]
        chrom = result_final__['chromosome'][i]
        pos = result_final__['position'][i]
        gene = regions[chrom][start-1:end]
        if pos > start and pos < end:
        
            if result_final__['strand'][i] == '+':
                #decide which allele to use
                #check 
                #check how long the y0036 allele is 
                all1_len = len(result_final__['allele_1'][i])
                all2_len = len(result_final__['allele_2'][i])
                #check if y0036 allele matches the reference allele
                
                if result_final__['reference_seq_'][i][3:3+all2_len] == result_final__['allele_2'][i]:
                    mutation = result_final__['allele_1'][i]

                elif result_final__['reference_seq_'][i][3:3+all1_len] == result_final__['allele_1'][i]:
                    #if yes, use x968 allele
                    mutation = result_final__['allele_2'][i]
                else:
                    print(i)

                gene = gene[:pos-start] + mutation + gene[pos-start+1:]
            elif result_final__['strand'][i] == '-':
                
                gene = gene[::-1]
            
                gene = ''.join(gene)

                all1_len = len(result_final__['allele_1'][i])
                all2_len = len(result_final__['allele_2'][i])
                
                if result_final__['reference_seq_'][i][3:3-all2_len] == result_final__['allele_2'][i]:
                    mutation = result_final__['allele_1'][i]
                elif result_final__['reference_seq_'][i][3:3-all1_len] == result_final__['allele_1'][i]:
                    mutation = result_final__['allele_2'][i]
                
                else:
                    print(i)
                
                gene = gene[:end-pos] + mutation + gene[end-pos+1:]

                
            if len(gene)%3 != 0:
                gene = gene[:-(len(gene)%3)]
            gene = [gene[i:i+3] for i in range(0, len(gene), 3)]
                #only triplets near the position
            if result_final__['strand'][i] == '+':
                gene = gene[(pos-start)//3-4:(pos-end)//3+4]
            else:
                gene = gene[(end-pos)//3-4:(start-pos)//3+4]
            result_final__["mutant allele"][i] = gene
######
# Out:
# 2
# 32
# 98
# 115
# 175
# 193
# 216
# 242
# 257
# 280
# 297
# 314
# 331
# 412
# 416

# %%
result_final__['wt_gene'] = np.nan
#iterate through result_final__ positions. If object is CDS, then look up the sequence from start to end in regions.
#add the sequence to the df
for i in range(len(result_final__)):
    
    if result_final__['object'][i] == 'CDS':
    
        start = result_final__['start'][i]
        end = result_final__['end'][i]
        chrom = result_final__['chromosome'][i]
        pos = result_final__['position'][i]
        gene = regions[chrom][start-1:end]
        if pos > start and pos < end:
        
            if result_final__['strand'][i] == '-':
                
                gene = gene[::-1]
            
                gene = ''.join(gene)
            #write the gene as triplets of letters like AAA, ATC, etc
            #if divisible by 3
            if len(gene)%3 != 0:
                gene = gene[:-(len(gene)%3)]
            gene = [gene[i:i+3] for i in range(0, len(gene), 3)]
                #only triplets near the position
            if result_final__['strand'][i] == '+':
                gene = gene[(pos-start)//3-3:(pos-end)//3+3]
            else: 
                gene = gene[(end-pos)//3-3:(start-pos)//3+3]
            
                
                


            result_final__['wt_gene'][i] = gene

result_final__['mutant allele'] = np.nan
for i in range(len(result_final__)):
    if result_final__['object'][i] == 'CDS':
    
        start = result_final__['start'][i]
        end = result_final__['end'][i]
        chrom = result_final__['chromosome'][i]
        pos = result_final__['position'][i]
        gene = regions[chrom][start-1:end]
        if pos > start and pos < end:
            mutation = ""
            if result_final__['strand'][i] == '+':
                #decide which allele to use
                #check 
                #check how long the y0036 allele is 
                all1_len = len(result_final__['allele_1'][i])
                #check if y0036 allele matches the reference allele
                
                if result_final__['reference_seq_'][i][3:(3+all1_len)] == result_final__['allele_1'][i]:
                    mutation = result_final__['allele_2'][i]
                else:
                    print("if1" + str(i))

                gene = gene[:pos-start] + mutation + gene[pos-start+1:]
            elif result_final__['strand'][i] == '-':
                
                gene = gene[::-1]
            
                gene = ''.join(gene)

                all1_len = len(result_final__['allele_1'][i])
                
                
                if result_final__['reference_seq_'][i][(4-all1_len):4] == result_final__['allele_1'][i]:
                    mutation = result_final__['allele_2'][i]
                
                else:
                    print("if2" + str(i))
                
                gene = gene[:end-pos] + mutation + gene[end-pos+1:]

                
            if len(gene)%3 != 0:
                gene = gene[:-(len(gene)%3)]
            gene = [gene[i:i+3] for i in range(0, len(gene), 3)]
                #only triplets near the position
            if result_final__['strand'][i] == '+':
                gene = gene[(pos-start)//3-3:(pos-end)//3+3]
            else:
                gene = gene[(end-pos)//3-3:(start-pos)//3+3]
            result_final__["mutant allele"][i] = gene
# Out:
# if2416

# %%
result_final__.head(50)
# Out:
#     position            ID          Parent                object chromosome  \
# 0    3364859  SPAC26A3.13c           Tf2-4                  gene          I
# 1    3364859  SPAC26A3.13c    SPAC26A3.13c                  mRNA          I
# 2    3364859  SPAC26A3.13c  SPAC26A3.13c.1                   CDS          I
# 3    3364859  SPAC26A3.14c            None                  gene          I
# 4    3364859  SPAC26A3.14c    SPAC26A3.14c                  mRNA          I
# 5    3364859  SPAC26A3.14c  SPAC26A3.14c.1       three_prime_UTR          I
# 6    3364859  SPNCRNA.3503            None                  gene          I
# 7    3364859  SPNCRNA.3503    SPNCRNA.3503                 ncRNA          I
# 8    3364859  SPNCRNA.3503  SPNCRNA.3503.1                   CDS          I
# 9    3364859  SPNCRNA.3504            None                  gene          I
# 10   3364859  SPNCRNA.3504    SPNCRNA.3504                 ncRNA          I
# 11   3364859  SPNCRNA.3504  SPNCRNA.3504.1                   CDS          I
# 12   3364859  SPNCRNA.3505            None                  gene          I
# 13   3364859  SPNCRNA.3505    SPNCRNA.3505                 ncRNA          I
# 14   3364859  SPNCRNA.3505  SPNCRNA.3505.1                   CDS          I
# 15   3364859        SPTF.5            None   LTR_retrotransposon          I
# 16   3364859     SPLTRA.55            None  long_terminal_repeat          I
# 17   3585317  SPAC17A2.13c           rad25                  gene          I
# 18   3585317  SPAC17A2.13c    SPAC17A2.13c                  mRNA          I
# 19   3585317  SPAC17A2.13c  SPAC17A2.13c.1        five_prime_UTR          I
# 20   3585317  SPAC17A2.13c  SPAC17A2.13c.1                   CDS          I
# 21   3585317  SPAC17A2.13c  SPAC17A2.13c.1                intron          I
# 22   3585317  SPAC17A2.13c  SPAC17A2.13c.1                   CDS          I
# 23   3585317   SPAC17A2.14            mnr2                  gene          I
# 24   3585317   SPAC17A2.14     SPAC17A2.14                  mRNA          I
# 25   3585317   SPAC17A2.14   SPAC17A2.14.1        five_prime_UTR          I
# 26   3585317   SPAC17A2.14   SPAC17A2.14.1                   CDS          I
# 27   3585317  SPNCRNA.3602            None                  gene          I
# 28   3585317  SPNCRNA.3602    SPNCRNA.3602                 ncRNA          I
# 29   3585317  SPNCRNA.3602  SPNCRNA.3602.1                   CDS          I
# 30   3585317   SPNCRNA.919            None                  gene          I
# 31   3585317   SPNCRNA.919     SPNCRNA.919                 ncRNA          I
# 32   3585317   SPNCRNA.919   SPNCRNA.919.1                   CDS          I
# 33   3585317   SPNCRNA.920            None                  gene          I
# 34   3585317   SPNCRNA.920     SPNCRNA.920                 ncRNA          I
# 35   3585317   SPNCRNA.920   SPNCRNA.920.1                   CDS          I
# 36   3585317     SPLTRA.58            None  long_terminal_repeat          I
# 37   4296875  SPBC16A3.02c            None                  gene         II
# 38   4296875  SPBC16A3.02c    SPBC16A3.02c                  mRNA         II
# 39   4296875  SPBC16A3.02c  SPBC16A3.02c.1        five_prime_UTR         II
# 40   4296875  SPBC16A3.02c  SPBC16A3.02c.1                   CDS         II
# 41   4296875  SPBC16A3.03c            ppr7                  gene         II
# 42   4296875  SPBC16A3.03c    SPBC16A3.03c                  mRNA         II
# 43   4296875  SPBC16A3.03c  SPBC16A3.03c.1                   CDS         II
# 44   4296875  SPBC16A3.03c  SPBC16A3.03c.1       three_prime_UTR         II
# 45   4296875  SPNCRNA.6532            None                  gene         II
# 46   4296875  SPNCRNA.6532    SPNCRNA.6532                 ncRNA         II
# 47   4296875  SPNCRNA.6532  SPNCRNA.6532.1                   CDS         II
# 48   4296875  SPNCRNA.6533            None                  gene         II
# 49   4296875  SPNCRNA.6533    SPNCRNA.6533                 ncRNA         II
#
#       start      end strand           detail      beta       p_value type  \
# 0   3361547  3365548      -             None  0.546460  1.620139e-09  snp
# 1   3361547  3365548      -             None  0.546460  1.620139e-09  snp
# 2   3361547  3365548      -             exon  0.546460  1.620139e-09  snp
# 3   3366317  3367205      -             None  0.546460  1.620139e-09  snp
# 4   3366317  3367205      -             None  0.546460  1.620139e-09  snp
# 5   3366317  3366742      -  three_prime_UTR  0.546460  1.620139e-09  snp
# 6   3364029  3364812      +             None  0.546460  1.620139e-09  snp
# 7   3364029  3364812      +             None  0.546460  1.620139e-09  snp
# 8   3364029  3364812      +             exon  0.546460  1.620139e-09  snp
# 9   3365076  3365865      +             None  0.546460  1.620139e-09  snp
# 10  3365076  3365865      +             None  0.546460  1.620139e-09  snp
# 11  3365076  3365865      +             exon  0.546460  1.620139e-09  snp
# 12  3366144  3367500      +             None  0.546460  1.620139e-09  snp
# 13  3366144  3367500      +             None  0.546460  1.620139e-09  snp
# 14  3366144  3367500      +             exon  0.546460  1.620139e-09  snp
# 15  3361143  3366062      -             None  0.546460  1.620139e-09  snp
# 16  3365714  3366062      -             None  0.546460  1.620139e-09  snp
# 17  3583128  3584899      -             None -0.366654  6.328207e-08  snp
# 18  3583128  3584899      -             None -0.366654  6.328207e-08  snp
# 19  3584780  3584899      -   five_prime_UTR -0.366654  6.328207e-08  snp
# 20  3584713  3584779      -             exon -0.366654  6.328207e-08  snp
# 21  3583996  3584712      -           intron -0.366654  6.328207e-08  snp
# 22  3583250  3583995      -             exon -0.366654  6.328207e-08  snp
# 23  3586167  3588777      +             None -0.366654  6.328207e-08  snp
# 24  3586167  3588777      +             None -0.366654  6.328207e-08  snp
# 25  3586167  3586434      +   five_prime_UTR -0.366654  6.328207e-08  snp
# 26  3586435  3588288      +             exon -0.366654  6.328207e-08  snp
# 27  3586123  3588320      -             None -0.366654  6.328207e-08  snp
# 28  3586123  3588320      -             None -0.366654  6.328207e-08  snp
# 29  3586123  3588320      -             exon -0.366654  6.328207e-08  snp
# 30  3584833  3585787      -             None -0.366654  6.328207e-08  snp
# 31  3584833  3585787      -             None -0.366654  6.328207e-08  snp
# 32  3584833  3585787      -             exon -0.366654  6.328207e-08  snp
# 33  3584979  3586233      +             None -0.366654  6.328207e-08  snp
# 34  3584979  3586233      +             None -0.366654  6.328207e-08  snp
# 35  3584979  3586233      +             exon -0.366654  6.328207e-08  snp
# 36  3586218  3586423      +             None -0.366654  6.328207e-08  snp
# 37  4296979  4298874      +             None  0.443424  8.445186e-08  snp
# 38  4296979  4298874      +             None  0.443424  8.445186e-08  snp
# 39  4296979  4297583      +   five_prime_UTR  0.443424  8.445186e-08  snp
# 40  4297584  4298627      +             exon  0.443424  8.445186e-08  snp
# 41  4293219  4296025      +             None  0.443424  8.445186e-08  snp
# 42  4293219  4296025      +             None  0.443424  8.445186e-08  snp
# 43  4293597  4295573      +             exon  0.443424  8.445186e-08  snp
# 44  4295574  4296025      +  three_prime_UTR  0.443424  8.445186e-08  snp
# 45  4294696  4296412      -             None  0.443424  8.445186e-08  snp
# 46  4294696  4296412      -             None  0.443424  8.445186e-08  snp
# 47  4294696  4296412      -             exon  0.443424  8.445186e-08  snp
# 48  4296590  4296958      +             None  0.443424  8.445186e-08  snp
# 49  4296590  4296958      +             None  0.443424  8.445186e-08  snp
#
#     correlation  p_value_corr          gene albicans_name(s)  \
# 0           NaN           NaN         Tf2-4              NaN
# 1           NaN           NaN         Tf2-4              NaN
# 2           NaN           NaN         Tf2-4              NaN
# 3     -0.399422      0.001896  SPAC26A3.14c              NaN
# 4     -0.399422      0.001896  SPAC26A3.14c              NaN
# 5     -0.399422      0.001896  SPAC26A3.14c              NaN
# 6           NaN           NaN           NaN              NaN
# 7           NaN           NaN           NaN              NaN
# 8           NaN           NaN           NaN              NaN
# 9           NaN           NaN           NaN              NaN
# 10          NaN           NaN           NaN              NaN
# 11          NaN           NaN           NaN              NaN
# 12          NaN           NaN           NaN              NaN
# 13          NaN           NaN           NaN              NaN
# 14          NaN           NaN           NaN              NaN
# 15          NaN           NaN           NaN              NaN
# 16          NaN           NaN           NaN              NaN
# 17     0.022739      0.865462         rad25  ['C1_03220C_A']
# 18     0.022739      0.865462         rad25  ['C1_03220C_A']
# 19     0.022739      0.865462         rad25  ['C1_03220C_A']
# 20     0.022739      0.865462         rad25  ['C1_03220C_A']
# 21     0.022739      0.865462         rad25  ['C1_03220C_A']
# 22     0.022739      0.865462         rad25  ['C1_03220C_A']
# 23     0.198895      0.134454          mnr2              NaN
# 24     0.198895      0.134454          mnr2              NaN
# 25     0.198895      0.134454          mnr2              NaN
# 26     0.198895      0.134454          mnr2              NaN
# 27          NaN           NaN           NaN              NaN
# 28          NaN           NaN           NaN              NaN
# 29          NaN           NaN           NaN              NaN
# 30     0.147888      0.267917   SPNCRNA.919              NaN
# 31     0.147888      0.267917   SPNCRNA.919              NaN
# 32     0.147888      0.267917   SPNCRNA.919              NaN
# 33    -0.140556      0.292627   SPNCRNA.920              NaN
# 34    -0.140556      0.292627   SPNCRNA.920              NaN
# 35    -0.140556      0.292627   SPNCRNA.920              NaN
# 36          NaN           NaN           NaN              NaN
# 37     0.229019      0.083764  SPBC16A3.02c              NaN
# 38     0.229019      0.083764  SPBC16A3.02c              NaN
# 39     0.229019      0.083764  SPBC16A3.02c              NaN
# 40     0.229019      0.083764  SPBC16A3.02c              NaN
# 41    -0.192218      0.148305          ppr7              NaN
# 42    -0.192218      0.148305          ppr7              NaN
# 43    -0.192218      0.148305          ppr7              NaN
# 44    -0.192218      0.148305          ppr7              NaN
# 45          NaN           NaN           NaN              NaN
# 46          NaN           NaN           NaN              NaN
# 47          NaN           NaN           NaN              NaN
# 48          NaN           NaN           NaN              NaN
# 49          NaN           NaN           NaN              NaN
#
#        cerevisiae_name(s) allele_1 allele_2 reference_seq reference_seq_  \
# 0                     NaN        C        T   CTT |C| TGT        CTTCTGT
# 1                     NaN        C        T   CTT |C| TGT        CTTCTGT
# 2                     NaN        C        T   CTT |C| TGT        CTTCTGT
# 3                     NaN        C        T   CTT |C| TGT        CTTCTGT
# 4                     NaN        C        T   CTT |C| TGT        CTTCTGT
# 5                     NaN        C        T   CTT |C| TGT        CTTCTGT
# 6                     NaN        C        T   TGT |C| TTC        TGTCTTC
# 7                     NaN        C        T   TGT |C| TTC        TGTCTTC
# 8                     NaN        C        T   TGT |C| TTC        TGTCTTC
# 9                     NaN        C        T   TGT |C| TTC        TGTCTTC
# 10                    NaN        C        T   TGT |C| TTC        TGTCTTC
# 11                    NaN        C        T   TGT |C| TTC        TGTCTTC
# 12                    NaN        C        T   TGT |C| TTC        TGTCTTC
# 13                    NaN        C        T   TGT |C| TTC        TGTCTTC
# 14                    NaN        C        T   TGT |C| TTC        TGTCTTC
# 15                    NaN        C        T   CTT |C| TGT        CTTCTGT
# 16                    NaN        C        T   CTT |C| TGT        CTTCTGT
# 17  ['YDR099W' 'YER177W']        A        C   TTA |A| AGC        TTAAAGC
# 18  ['YDR099W' 'YER177W']        A        C   TTA |A| AGC        TTAAAGC
# 19  ['YDR099W' 'YER177W']        A        C   TTA |A| AGC        TTAAAGC
# 20  ['YDR099W' 'YER177W']        A        C   TTA |A| AGC        TTAAAGC
# 21  ['YDR099W' 'YER177W']        A        C   TTA |A| AGC        TTAAAGC
# 22  ['YDR099W' 'YER177W']        A        C   TTA |A| AGC        TTAAAGC
# 23                    NaN        A        C   CGA |A| ATT        CGAAATT
# 24                    NaN        A        C   CGA |A| ATT        CGAAATT
# 25                    NaN        A        C   CGA |A| ATT        CGAAATT
# 26                    NaN        A        C   CGA |A| ATT        CGAAATT
# 27                    NaN        A        C   TTA |A| AGC        TTAAAGC
# 28                    NaN        A        C   TTA |A| AGC        TTAAAGC
# 29                    NaN        A        C   TTA |A| AGC        TTAAAGC
# 30                    NaN        A        C   TTA |A| AGC        TTAAAGC
# 31                    NaN        A        C   TTA |A| AGC        TTAAAGC
# 32                    NaN        A        C   TTA |A| AGC        TTAAAGC
# 33                    NaN        A        C   CGA |A| ATT        CGAAATT
# 34                    NaN        A        C   CGA |A| ATT        CGAAATT
# 35                    NaN        A        C   CGA |A| ATT        CGAAATT
# 36                    NaN        A        C   CGA |A| ATT        CGAAATT
# 37                    NaN        T        A   TAT |T| AGT        TATTAGT
# 38                    NaN        T        A   TAT |T| AGT        TATTAGT
# 39                    NaN        T        A   TAT |T| AGT        TATTAGT
# 40                    NaN        T        A   TAT |T| AGT        TATTAGT
# 41                    NaN        T        A   TAT |T| AGT        TATTAGT
# 42                    NaN        T        A   TAT |T| AGT        TATTAGT
# 43                    NaN        T        A   TAT |T| AGT        TATTAGT
# 44                    NaN        T        A   TAT |T| AGT        TATTAGT
# 45                    NaN        T        A   TGA |T| TAT        TGATTAT
# 46                    NaN        T        A   TGA |T| TAT        TGATTAT
# 47                    NaN        T        A   TGA |T| TAT        TGATTAT
# 48                    NaN        T        A   TAT |T| AGT        TATTAGT
# 49                    NaN        T        A   TAT |T| AGT        TATTAGT
#
#                                 wt_gene                        mutant allele
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2   [TTG, GAC, TCC, TTC, TGT, TTA, CAA]  [TTG, GAC, TCC, TTT, TGT, TTA, CAA]
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# 5                                   NaN                                  NaN
# 6                                   NaN                                  NaN
# 7                                   NaN                                  NaN
# 8                                   NaN                                  NaN
# 9                                   NaN                                  NaN
# 10                                  NaN                                  NaN
# 11                                  NaN                                  NaN
# 12                                  NaN                                  NaN
# 13                                  NaN                                  NaN
# 14                                  NaN                                  NaN
# 15                                  NaN                                  NaN
# 16                                  NaN                                  NaN
# 17                                  NaN                                  NaN
# 18                                  NaN                                  NaN
# 19                                  NaN                                  NaN
# 20                                  NaN                                  NaN
# 21                                  NaN                                  NaN
# 22                                  NaN                                  NaN
# 23                                  NaN                                  NaN
# 24                                  NaN                                  NaN
# 25                                  NaN                                  NaN
# 26                                  NaN                                  NaN
# 27                                  NaN                                  NaN
# 28                                  NaN                                  NaN
# 29                                  NaN                                  NaN
# 30                                  NaN                                  NaN
# 31                                  NaN                                  NaN
# 32       [ATA, TTA, CCT, TAA, AGC, GGC]       [ATA, TTA, CCT, TAC, AGC, GGC]
# 33                                  NaN                                  NaN
# 34                                  NaN                                  NaN
# 35       [GGA, GGC, GGC, GAA, ATT, CCA]       [GGA, GGC, GGC, GAC, ATT, CCA]
# 36                                  NaN                                  NaN
# 37                                  NaN                                  NaN
# 38                                  NaN                                  NaN
# 39                                  NaN                                  NaN
# 40                                  NaN                                  NaN
# 41                                  NaN                                  NaN
# 42                                  NaN                                  NaN
# 43                                  NaN                                  NaN
# 44                                  NaN                                  NaN
# 45                                  NaN                                  NaN
# 46                                  NaN                                  NaN
# 47                                  NaN                                  NaN
# 48                                  NaN                                  NaN
# 49                                  NaN                                  NaN

# %%
#CreATE A DF WHERE WHOLE GENE IS NOT NAN
stop_codon_df = result_final__[result_final__['wt_gene'].notna()]
stop_codon_df["stop_codon_predicted"] = np.nan
#iterate through mutant allele, and see whether it contains
#reset index
stop_codon_df = stop_codon_df.reset_index(drop=True)

for i in range(len(stop_codon_df)):
    for j in range(len(stop_codon_df['mutant allele'][i])):
        if stop_codon_df["strand"][i] == '+':
            if stop_codon_df['mutant allele'][i][j] == 'TAA' or stop_codon_df['mutant allele'][i][j] == 'TAG' or stop_codon_df['mutant allele'][i][j] == 'TGA':
                stop_codon_df['stop_codon_predicted'][i] = 'yes'
        else:
            if stop_codon_df['mutant allele'][i][j] == 'ATT' or stop_codon_df['mutant allele'][i][j] == 'ATC' or stop_codon_df['mutant allele'][i][j] == 'ACT':
                stop_codon_df['stop_codon_predicted'][i] = 'yes'
#show which entries have a stop codon predicted
stop_codon_df[stop_codon_df['stop_codon_predicted'] == 'yes']
# Out:
#     position            ID          Parent object chromosome    start  \
# 3    4296875  SPNCRNA.6533  SPNCRNA.6533.1    CDS         II  4296590
# 4    4296877  SPNCRNA.6533  SPNCRNA.6533.1    CDS         II  4296590
# 7    2227937  SPNCRNA.7677  SPNCRNA.7677.1    CDS        III  2227612
# 9     498798  SPNCRNA.2204  SPNCRNA.2204.1    CDS          I   497961
# 18   2693728  SPNCRNA.5773  SPNCRNA.5773.1    CDS         II  2693622
# 19   2693728  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 20   2694024  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 22   2277085   SPNCRNA.516   SPNCRNA.516.1    CDS        III  2275648
#
#         end strand detail      beta  ...         gene albicans_name(s)  \
# 3   4296958      +   exon  0.443424  ...          NaN              NaN
# 4   4296958      +   exon  0.443424  ...          NaN              NaN
# 7   2228044      +   exon  0.558370  ...          NaN              NaN
# 9    498854      -   exon  0.311554  ...          NaN              NaN
# 18  2693887      +   exon -0.397447  ...          NaN              NaN
# 19  2694958      -   exon -0.397447  ...          NaN              NaN
# 20  2694958      -   exon -0.397447  ...          NaN              NaN
# 22  2277744      +   exon  0.401600  ...  SPNCRNA.516              NaN
#
#     cerevisiae_name(s)  allele_1 allele_2 reference_seq reference_seq_  \
# 3                  NaN         T        A   TAT |T| AGT        TATTAGT
# 4                  NaN         G        A   TTA |G| TGA        TTAGTGA
# 7                  NaN         T        G   TTC |T| GGC        TTCTGGC
# 9                  NaN        GT        T   GGG |T| TTA        GGGTTTA
# 18                 NaN        AC     AACA   AAA |A| CAA        AAAACAA
# 19                 NaN        CA     ACAA   AAC |A| AAA        AACAAAA
# 20                 NaN         A       TA   TTT |A| GAA        TTTAGAA
# 22                 NaN         T       TC   TTA |T| AAT        TTATAAT
#
#                                 wt_gene                        mutant allele  \
# 3        [GAG, CTA, TAT, TAG, TGA, TAG]       [GAG, CTA, TAT, AAG, TGA, TAG]
# 4   [GAG, CTA, TAT, TAG, TGA, TAG, GTA]  [GAG, CTA, TAT, TAA, TGA, TAG, GTA]
# 7        [TTT, TGA, ATT, CTG, GCT, TGG]       [TTT, TGA, ATT, CGG, GCT, TGG]
# 9   [CTT, TTG, GGG, GGT, TTA, ATT, AGT]  [CTT, TTG, GGG, GGT, TTA, ATT, AGT]
# 18       [GAC, TAA, AAA, AAC, AAA, AAA]  [GAC, TAA, AAA, AAA, CAC, AAA, AAA]
# 19       [CAA, AAA, AAC, AAA, AAA, ATC]  [CAA, AAA, AAC, ACA, AAA, AAA, ATC]
# 20       [ATA, TGA, ATT, TAG, AAA, ATT]       [ATA, TGA, ATT, TTA, GAA, AAT]
# 22       [CTT, GTC, TTA, TAA, TGT, AAA]       [CTT, GTC, TTA, TCA, ATG, TAA]
#
#    stop_codon_predicted
# 3                   yes
# 4                   yes
# 7                   yes
# 9                   yes
# 18                  yes
# 19                  yes
# 20                  yes
# 22                  yes
#
# [8 rows x 24 columns]

# %%
#show subset of result_final that are CDS and position is within the CDS and name doesnt start with SPNCRNA
result_final__[(result_final__['object'] == 'CDS') & (result_final__['position'] > result_final__['start']) & (result_final__['position'] < result_final__['end'] ) & (result_final__['ID'].str.startswith('SPNCRNA') == False)]
# Out:
#      position            ID          Parent object chromosome    start  \
# 2     3364859  SPAC26A3.13c  SPAC26A3.13c.1    CDS          I  3361547
# 55    2227937  SPCC1919.10c  SPCC1919.10c.1    CDS        III  2225048
# 64    2228740  SPCC1919.10c  SPCC1919.10c.1    CDS        III  2225048
# 215   2291604   SPCC965.05c   SPCC965.05c.1    CDS        III  2291004
#
#          end strand detail     beta  ...  p_value_corr   gene  \
# 2    3365548      -   exon  0.54646  ...           NaN  Tf2-4
# 55   2229460      -   exon  0.55837  ...      0.014482  myo52
# 64   2229460      -   exon  0.55837  ...      0.014482  myo52
# 215  2291981      -   exon  0.40160  ...      0.695544   thp1
#
#      albicans_name(s)     cerevisiae_name(s)                      allele_1  \
# 2                 NaN                    NaN                             C
# 55    ['C1_13780W_A']  ['YAL029C' 'YOR326W']                             T
# 64    ['C1_13780W_A']  ['YAL029C' 'YOR326W']                             C
# 215               NaN                    NaN  ATGGGAGTTTCGTAGACAATTCTTTTCG
#
#     allele_2 reference_seq reference_seq_  \
# 2          T   CTT |C| TGT        CTTCTGT
# 55         G   CGG |T| CTT        CGGTCTT
# 64         T   AGC |C| TTG        AGCCTTG
# 215        G   TTC |G| TGC        TTCGTGC
#
#                                  wt_gene                        mutant allele
# 2    [TTG, GAC, TCC, TTC, TGT, TTA, CAA]  [TTG, GAC, TCC, TTT, TGT, TTA, CAA]
# 55   [AAG, AGG, TTC, GGT, CTT, AAG, TTT]  [AAG, AGG, TTC, GGG, CTT, AAG, TTT]
# 64        [AGT, AGG, AGC, CTT, GTT, GAA]       [AGT, AGG, AGC, TTT, GTT, GAA]
# 215  [CAA, TTC, TTT, TCG, TGC, GAA, TTT]       [CAA, TTC, TTT, TCT, GCG, AAT]
#
# [4 rows x 23 columns]

# %%
#in stop_codon_df create a column "possible frameshift" and fill it with nan. Then loop through X96_allele and Y0036_allele and check if the length is different. If yes and the difference is not divisible by 3, fill the column with "yes". Then show the entries where the column is "yes"
frameshift_df = stop_codon_df.copy()
frameshift_df['possible frameshift'] = np.nan
for i in range(len(frameshift_df)):
    if len(frameshift_df['allele_1'][i]) != len(frameshift_df['allele_2'][i]):
        if (len(frameshift_df['allele_1'][i]) - len(frameshift_df['allele_2'][i]))%3 != 0:
            frameshift_df['possible frameshift'][i] = 'yes'
frameshift_df[frameshift_df['possible frameshift'] == 'yes']
# Out:
#     position            ID          Parent object chromosome    start  \
# 9     498798  SPNCRNA.2204  SPNCRNA.2204.1    CDS          I   497961
# 10    519884  SPNCRNA.2211  SPNCRNA.2211.1    CDS          I   519783
# 11    519884   SPNCRNA.658   SPNCRNA.658.1    CDS          I   519257
# 12    522785  SPNCRNA.2214  SPNCRNA.2214.1    CDS          I   521928
# 13    723772  SPNCRNA.2311  SPNCRNA.2311.1    CDS          I   723712
# 14   1721443  SPNCRNA.1457  SPNCRNA.1457.1    CDS         II  1721083
# 15   1721443   SPNCRNA.376   SPNCRNA.376.1    CDS         II  1721073
# 16   2693701  SPNCRNA.5773  SPNCRNA.5773.1    CDS         II  2693622
# 17   2693701  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 18   2693728  SPNCRNA.5773  SPNCRNA.5773.1    CDS         II  2693622
# 19   2693728  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 20   2694024  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 21   2694637  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 22   2277085   SPNCRNA.516   SPNCRNA.516.1    CDS        III  2275648
# 23   2277085  SPNCRNA.7699  SPNCRNA.7699.1    CDS        III  2276821
#
#         end strand detail      beta   p_value   type  correlation  \
# 9    498854      -   exon  0.311554  0.000089  indel          NaN
# 10   520113      -   exon  0.349112  0.000029  indel          NaN
# 11   520194      +   exon  0.349112  0.000029  indel     0.191849
# 12   524210      -   exon  0.479528  0.000009  indel          NaN
# 13   724313      -   exon  0.417287  0.000025  indel          NaN
# 14  1724641      -   exon -0.285830  0.000009  indel     0.092063
# 15  1721574      +   exon -0.285830  0.000009  indel     0.065749
# 16  2693887      +   exon -0.397447  0.000005  indel          NaN
# 17  2694958      -   exon -0.397447  0.000005  indel          NaN
# 18  2693887      +   exon -0.397447  0.000005  indel          NaN
# 19  2694958      -   exon -0.397447  0.000005  indel          NaN
# 20  2694958      -   exon -0.397447  0.000005  indel          NaN
# 21  2694958      -   exon -0.397447  0.000005  indel          NaN
# 22  2277744      +   exon  0.401600  0.000085  indel    -0.237347
# 23  2277672      -   exon  0.401600  0.000085  indel          NaN
#
#     p_value_corr               gene albicans_name(s) cerevisiae_name(s)  \
# 9            NaN                NaN              NaN                NaN
# 10           NaN                NaN              NaN                NaN
# 11      0.149101        SPNCRNA.658              NaN                NaN
# 12           NaN                NaN              NaN                NaN
# 13           NaN                NaN              NaN                NaN
# 14      0.491875  atf21-antisense-1              NaN                NaN
# 15      0.623881        SPNCRNA.376              NaN                NaN
# 16           NaN                NaN              NaN                NaN
# 17           NaN                NaN              NaN                NaN
# 18           NaN                NaN              NaN                NaN
# 19           NaN                NaN              NaN                NaN
# 20           NaN                NaN              NaN                NaN
# 21           NaN                NaN              NaN                NaN
# 22      0.072819        SPNCRNA.516              NaN                NaN
# 23           NaN                NaN              NaN                NaN
#
#    allele_1 allele_2 reference_seq reference_seq_  \
# 9        GT        T   GGG |T| TTA        GGGTTTA
# 10        A       TA   GAT |A| CCT        GATACCT
# 11        A       AT   TCC |A| TAG        TCCATAG
# 12        A       TA   TTT |A| TCG        TTTATCG
# 13        T   CTCTGT   CTG |T| TTT        CTGTTTT
# 14        A      TCA   CTC |A| TTG        CTCATTG
# 15        A      ACT   GTT |A| CTC        GTTACTC
# 16       GT        G   TTT |G| TTT        TTTGTTT
# 17       TG        G   TTT |G| TTT        TTTGTTT
# 18       AC     AACA   AAA |A| CAA        AAAACAA
# 19       CA     ACAA   AAC |A| AAA        AACAAAA
# 20        A       TA   TTT |A| GAA        TTTAGAA
# 21        G       TG   CTG |G| TTT        CTGGTTT
# 22        T       TC   TTA |T| AAT        TTATAAT
# 23        T       CT   TAA |T| ATT        TAATATT
#
#                                 wt_gene  \
# 9   [CTT, TTG, GGG, GGT, TTA, ATT, AGT]
# 10       [GGT, CGT, TGA, TAC, CTG, AGC]
# 11            [AGC, GAG, TCC, ATA, GTT]
# 12       [AAA, CTT, TTT, ATC, GGG, GAT]
# 13       [AAT, TTC, TCT, GTT, TTT, ATG]
# 14       [TTC, GTT, CTC, ATT, GTA, CAA]
# 15       [ATA, ACA, TGT, TAC, TCT, TGC]
# 16       [ACC, AGT, TTT, TGT, TTT, TTT]
# 17       [TTT, TTT, TTT, GTT, TTT, GAC]
# 18       [GAC, TAA, AAA, AAC, AAA, AAA]
# 19       [CAA, AAA, AAC, AAA, AAA, ATC]
# 20       [ATA, TGA, ATT, TAG, AAA, ATT]
# 21       [TAT, TTG, CTG, GTT, TTT, TAT]
# 22       [CTT, GTC, TTA, TAA, TGT, AAA]
# 23  [CAA, AAA, TGT, AAT, ATT, CTG, TTC]
#
#                                mutant allele stop_codon_predicted  \
# 9        [CTT, TTG, GGG, GGT, TTA, ATT, AGT]                  yes
# 10            [GGT, CGT, TGA, TTA, CCT, GAG]                  NaN
# 11            [AGC, GAG, TCC, ATT, AGT, TGC]                  NaN
# 12            [AAA, CTT, TTT, TAT, CGG, GGA]                  NaN
# 13  [AAT, TTC, TCT, GCT, CTG, TTT, TTA, TGC]                  NaN
# 14       [TTC, GTT, CTC, TCA, TTG, TAC, AAT]                  NaN
# 15       [ATA, ACA, TGT, TAC, TCT, CTT, GCT]                  NaN
# 16            [ACC, AGT, TTT, TGT, TTT, TTT]                  NaN
# 17            [TTT, TTT, TTT, GTT, TTT, GAC]                  NaN
# 18       [GAC, TAA, AAA, AAA, CAC, AAA, AAA]                  yes
# 19       [CAA, AAA, AAC, ACA, AAA, AAA, ATC]                  yes
# 20            [ATA, TGA, ATT, TTA, GAA, AAT]                  yes
# 21            [TAT, TTG, CTG, TGT, TTT, TTA]                  NaN
# 22            [CTT, GTC, TTA, TCA, ATG, TAA]                  yes
# 23       [CAA, AAA, TGT, AAC, TAT, TCT, GTT]                  NaN
#
#    possible frameshift
# 9                  yes
# 10                 yes
# 11                 yes
# 12                 yes
# 13                 yes
# 14                 yes
# 15                 yes
# 16                 yes
# 17                 yes
# 18                 yes
# 19                 yes
# 20                 yes
# 21                 yes
# 22                 yes
# 23                 yes

# %%
#import a codon table as a dictionary
codon_table = {
    'TTT': 'F', 'TTC': 'F', 'TTA': 'L', 'TTG': 'L',
    'TCT': 'S', 'TCC': 'S', 'TCA': 'S', 'TCG': 'S',
    'TAT': 'Y', 'TAC': 'Y', 'TAA': '*', 'TAG': '*',
    'TGT': 'C', 'TGC': 'C', 'TGA': '*', 'TGG': 'W',
    'CTT': 'L', 'CTC': 'L', 'CTA': 'L', 'CTG': 'L',
    'CCT': 'P', 'CCC': 'P', 'CCA': 'P', 'CCG': 'P',
    'CAT': 'H', 'CAC': 'H', 'CAA': 'Q', 'CAG': 'Q', 
    'CGT': 'R', 'CGC': 'R', 'CGA': 'R', 'CGG': 'R',
    'ATT': 'I', 'ATC': 'I', 'ATA': 'I', 'ATG': 'M',
    'ACT': 'T', 'ACC': 'T', 'ACA': 'T', 'ACG': 'T',
    'AAT': 'N', 'AAC': 'N', 'AAA': 'K', 'AAG': 'K',
    'AGT': 'S', 'AGC': 'S', 'AGA': 'R', 'AGG': 'R',
    'GTT': 'V', 'GTC': 'V', 'GTA': 'V', 'GTG': 'V',
    'GCT': 'A', 'GCC': 'A', 'GCA': 'A', 'GCG': 'A',
    'GAT': 'D', 'GAC': 'D', 'GAA': 'E', 'GAG': 'E',
    'GGT': 'G', 'GGC': 'G', 'GGA': 'G', 'GGG': 'G',
}
#iterate through frameshift_df and trnslate the lists of triplets found in wt_gene and mutant allele
frameshift_df['wt_gene_translated'] = np.nan
frameshift_df['mutant allele_translated'] = np.nan
for i in range(len(frameshift_df)):
    #if strand is -, then change a to t and so on
    if frameshift_df['strand'][i] == '-':
        temp_wt_allele = frameshift_df['wt_gene'][i]
        temp_mut_allele = frameshift_df['mutant allele'][i]
        for j in range(len(temp_wt_allele)):
            temp_wt_allele[j] = temp_wt_allele[j].replace('A','t')
            temp_wt_allele[j] = temp_wt_allele[j].replace('T','a')
            temp_wt_allele[j] = temp_wt_allele[j].replace('C','g')
            temp_wt_allele[j] = temp_wt_allele[j].replace('G','c')
            temp_wt_allele[j] = temp_wt_allele[j].upper()
        for j in range(len(temp_mut_allele)):
            temp_mut_allele[j] = temp_mut_allele[j].replace('A','t')
            temp_mut_allele[j] = temp_mut_allele[j].replace('T','a')
            temp_mut_allele[j] = temp_mut_allele[j].replace('C','g')
            temp_mut_allele[j] = temp_mut_allele[j].replace('G','c')
            temp_mut_allele[j] = temp_mut_allele[j].upper()
        frameshift_df['wt_gene_translated'][i] = ''.join([codon_table[codon] for codon in temp_wt_allele])
        frameshift_df['mutant allele_translated'][i] = ''.join([codon_table[codon] for codon in temp_mut_allele])
    else:
        frameshift_df['wt_gene_translated'][i] = ''.join([codon_table[codon] for codon in frameshift_df['wt_gene'][i]])
        frameshift_df['mutant allele_translated'][i] = ''.join([codon_table[codon] for codon in frameshift_df['mutant allele'][i]])

# %%
#DISPLAY all columns
pd.set_option('display.max_columns', None)

# %%
frameshift_df
# Out:
#     position            ID          Parent object chromosome    start  \
# 0    3364859  SPAC26A3.13c  SPAC26A3.13c.1    CDS          I  3361547
# 1    3585317   SPNCRNA.919   SPNCRNA.919.1    CDS          I  3584833
# 2    3585317   SPNCRNA.920   SPNCRNA.920.1    CDS          I  3584979
# 3    4296875  SPNCRNA.6533  SPNCRNA.6533.1    CDS         II  4296590
# 4    4296877  SPNCRNA.6533  SPNCRNA.6533.1    CDS         II  4296590
# 5    2219006  SPNCRNA.7673  SPNCRNA.7673.1    CDS        III  2218876
# 6    2227937  SPCC1919.10c  SPCC1919.10c.1    CDS        III  2225048
# 7    2227937  SPNCRNA.7677  SPNCRNA.7677.1    CDS        III  2227612
# 8    2228740  SPCC1919.10c  SPCC1919.10c.1    CDS        III  2225048
# 9     498798  SPNCRNA.2204  SPNCRNA.2204.1    CDS          I   497961
# 10    519884  SPNCRNA.2211  SPNCRNA.2211.1    CDS          I   519783
# 11    519884   SPNCRNA.658   SPNCRNA.658.1    CDS          I   519257
# 12    522785  SPNCRNA.2214  SPNCRNA.2214.1    CDS          I   521928
# 13    723772  SPNCRNA.2311  SPNCRNA.2311.1    CDS          I   723712
# 14   1721443  SPNCRNA.1457  SPNCRNA.1457.1    CDS         II  1721083
# 15   1721443   SPNCRNA.376   SPNCRNA.376.1    CDS         II  1721073
# 16   2693701  SPNCRNA.5773  SPNCRNA.5773.1    CDS         II  2693622
# 17   2693701  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 18   2693728  SPNCRNA.5773  SPNCRNA.5773.1    CDS         II  2693622
# 19   2693728  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 20   2694024  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 21   2694637  SPNCRNA.5774  SPNCRNA.5774.1    CDS         II  2693641
# 22   2277085   SPNCRNA.516   SPNCRNA.516.1    CDS        III  2275648
# 23   2277085  SPNCRNA.7699  SPNCRNA.7699.1    CDS        III  2276821
# 24   2291604   SPCC965.05c   SPCC965.05c.1    CDS        III  2291004
# 25   2357290  SPNCRNA.7727  SPNCRNA.7727.1    CDS        III  2354421
#
#         end strand detail      beta       p_value   type  correlation  \
# 0   3365548      -   exon  0.546460  1.620139e-09    snp          NaN
# 1   3585787      -   exon -0.366654  6.328207e-08    snp     0.147888
# 2   3586233      +   exon -0.366654  6.328207e-08    snp    -0.140556
# 3   4296958      +   exon  0.443424  8.445186e-08    snp          NaN
# 4   4296958      +   exon  0.443424  8.445186e-08    snp          NaN
# 5   2220006      +   exon  0.471360  1.374737e-08    snp          NaN
# 6   2229460      -   exon  0.558370  1.963371e-10    snp    -0.319543
# 7   2228044      +   exon  0.558370  1.963371e-10    snp          NaN
# 8   2229460      -   exon  0.558370  1.963371e-10    snp    -0.319543
# 9    498854      -   exon  0.311554  8.916224e-05  indel          NaN
# 10   520113      -   exon  0.349112  2.914204e-05  indel          NaN
# 11   520194      +   exon  0.349112  2.914204e-05  indel     0.191849
# 12   524210      -   exon  0.479528  9.351192e-06  indel          NaN
# 13   724313      -   exon  0.417287  2.522852e-05  indel          NaN
# 14  1724641      -   exon -0.285830  9.253300e-06  indel     0.092063
# 15  1721574      +   exon -0.285830  9.253300e-06  indel     0.065749
# 16  2693887      +   exon -0.397447  5.059658e-06  indel          NaN
# 17  2694958      -   exon -0.397447  5.059658e-06  indel          NaN
# 18  2693887      +   exon -0.397447  5.059658e-06  indel          NaN
# 19  2694958      -   exon -0.397447  5.059658e-06  indel          NaN
# 20  2694958      -   exon -0.397447  5.059658e-06  indel          NaN
# 21  2694958      -   exon -0.397447  5.059658e-06  indel          NaN
# 22  2277744      +   exon  0.401600  8.534981e-05  indel    -0.237347
# 23  2277672      -   exon  0.401600  8.534981e-05  indel          NaN
# 24  2291981      -   exon  0.401600  8.534981e-05  indel     0.052493
# 25  2358979      +   exon  0.393597  9.895852e-05  indel          NaN
#
#     p_value_corr               gene albicans_name(s)     cerevisiae_name(s)  \
# 0            NaN              Tf2-4              NaN                    NaN
# 1       0.267917        SPNCRNA.919              NaN                    NaN
# 2       0.292627        SPNCRNA.920              NaN                    NaN
# 3            NaN                NaN              NaN                    NaN
# 4            NaN                NaN              NaN                    NaN
# 5            NaN                NaN              NaN                    NaN
# 6       0.014482              myo52  ['C1_13780W_A']  ['YAL029C' 'YOR326W']
# 7            NaN                NaN              NaN                    NaN
# 8       0.014482              myo52  ['C1_13780W_A']  ['YAL029C' 'YOR326W']
# 9            NaN                NaN              NaN                    NaN
# 10           NaN                NaN              NaN                    NaN
# 11      0.149101        SPNCRNA.658              NaN                    NaN
# 12           NaN                NaN              NaN                    NaN
# 13           NaN                NaN              NaN                    NaN
# 14      0.491875  atf21-antisense-1              NaN                    NaN
# 15      0.623881        SPNCRNA.376              NaN                    NaN
# 16           NaN                NaN              NaN                    NaN
# 17           NaN                NaN              NaN                    NaN
# 18           NaN                NaN              NaN                    NaN
# 19           NaN                NaN              NaN                    NaN
# 20           NaN                NaN              NaN                    NaN
# 21           NaN                NaN              NaN                    NaN
# 22      0.072819        SPNCRNA.516              NaN                    NaN
# 23           NaN                NaN              NaN                    NaN
# 24      0.695544               thp1              NaN                    NaN
# 25           NaN                NaN              NaN                    NaN
#
#                         allele_1          allele_2 reference_seq  \
# 0                              C                 T   CTT |C| TGT
# 1                              A                 C   TTA |A| AGC
# 2                              A                 C   CGA |A| ATT
# 3                              T                 A   TAT |T| AGT
# 4                              G                 A   TTA |G| TGA
# 5                              A                 C   ACA |A| ATT
# 6                              T                 G   CGG |T| CTT
# 7                              T                 G   TTC |T| GGC
# 8                              C                 T   AGC |C| TTG
# 9                             GT                 T   GGG |T| TTA
# 10                             A                TA   GAT |A| CCT
# 11                             A                AT   TCC |A| TAG
# 12                             A                TA   TTT |A| TCG
# 13                             T            CTCTGT   CTG |T| TTT
# 14                             A               TCA   CTC |A| TTG
# 15                             A               ACT   GTT |A| CTC
# 16                            GT                 G   TTT |G| TTT
# 17                            TG                 G   TTT |G| TTT
# 18                            AC              AACA   AAA |A| CAA
# 19                            CA              ACAA   AAC |A| AAA
# 20                             A                TA   TTT |A| GAA
# 21                             G                TG   CTG |G| TTT
# 22                             T                TC   TTA |T| AAT
# 23                             T                CT   TAA |T| ATT
# 24  ATGGGAGTTTCGTAGACAATTCTTTTCG                 G   TTC |G| TGC
# 25                             C  CTTTTGATCTGATAAT   TAA |C| TTT
#
#    reference_seq_                              wt_gene  \
# 0         CTTCTGT  [AAC, CTG, AGG, AAG, ACA, AAT, GTT]
# 1         TTAAAGC       [TAT, AAT, GGA, ATT, TCG, CCG]
# 2         CGAAATT       [GGA, GGC, GGC, GAA, ATT, CCA]
# 3         TATTAGT       [GAG, CTA, TAT, TAG, TGA, TAG]
# 4         TTAGTGA  [GAG, CTA, TAT, TAG, TGA, TAG, GTA]
# 5         ACAAATT       [ACT, CTA, AAC, AAA, TTC, ATT]
# 6         CGGTCTT  [TTC, TCC, AAG, CCA, GAA, TTC, AAA]
# 7         TTCTGGC       [TTT, TGA, ATT, CTG, GCT, TGG]
# 8         AGCCTTG       [TCA, TCC, TCG, GAA, CAA, CTT]
# 9         GGGTTTA  [GAA, AAC, CCC, CCA, AAT, TAA, TCA]
# 10        GATACCT       [CCA, GCA, ACT, ATG, GAC, TCG]
# 11        TCCATAG            [AGC, GAG, TCC, ATA, GTT]
# 12        TTTATCG       [TTT, GAA, AAA, TAG, CCC, CTA]
# 13        CTGTTTT       [TTA, AAG, AGA, CAA, AAA, TAC]
# 14        CTCATTG       [AAG, CAA, GAG, TAA, CAT, GTT]
# 15        GTTACTC       [ATA, ACA, TGT, TAC, TCT, TGC]
# 16        TTTGTTT       [ACC, AGT, TTT, TGT, TTT, TTT]
# 17        TTTGTTT       [AAA, AAA, AAA, CAA, AAA, CTG]
# 18        AAAACAA       [GAC, TAA, AAA, AAC, AAA, AAA]
# 19        AACAAAA       [GTT, TTT, TTG, TTT, TTT, TAG]
# 20        TTTAGAA       [TAT, ACT, TAA, ATC, TTT, TAA]
# 21        CTGGTTT       [ATA, AAC, GAC, CAA, AAA, ATA]
# 22        TTATAAT       [CTT, GTC, TTA, TAA, TGT, AAA]
# 23        TAATATT  [GTT, TTT, ACA, TTA, TAA, GAC, AAG]
# 24        TTCGTGC  [GTT, AAG, AAA, AGC, ACG, CTT, AAA]
# 25        TAACTTT       [TCA, CGC, TTA, ACT, TTT, GAT]
#
#                                         mutant allele stop_codon_predicted  \
# 0                 [AAC, CTG, AGG, AAA, ACA, AAT, GTT]                  NaN
# 1                      [TAT, AAT, GGA, ATG, TCG, CCG]                  NaN
# 2                      [GGA, GGC, GGC, GAC, ATT, CCA]                  NaN
# 3                      [GAG, CTA, TAT, AAG, TGA, TAG]                  yes
# 4                 [GAG, CTA, TAT, TAA, TGA, TAG, GTA]                  yes
# 5                      [ACT, CTA, AAC, ACA, TTC, ATT]                  NaN
# 6                 [TTC, TCC, AAG, CCC, GAA, TTC, AAA]                  NaN
# 7                      [TTT, TGA, ATT, CGG, GCT, TGG]                  yes
# 8                      [TCA, TCC, TCG, AAA, CAA, CTT]                  NaN
# 9                 [GAA, AAC, CCC, CCA, AAT, TAA, TCA]                  yes
# 10                     [CCA, GCA, ACT, AAT, GGA, CTC]                  NaN
# 11                     [AGC, GAG, TCC, ATT, AGT, TGC]                  NaN
# 12                     [TTT, GAA, AAA, ATA, GCC, CCT]                  NaN
# 13           [TTA, AAG, AGA, CGA, GAC, AAA, AAT, ACG]                  NaN
# 14                [AAG, CAA, GAG, AGT, AAC, ATG, TTA]                  NaN
# 15                [ATA, ACA, TGT, TAC, TCT, CTT, GCT]                  NaN
# 16                     [ACC, AGT, TTT, TGT, TTT, TTT]                  NaN
# 17                     [AAA, AAA, AAA, CAA, AAA, CTG]                  NaN
# 18                [GAC, TAA, AAA, AAA, CAC, AAA, AAA]                  yes
# 19                [GTT, TTT, TTG, TGT, TTT, TTT, TAG]                  yes
# 20                     [TAT, ACT, TAA, AAT, CTT, TTA]                  yes
# 21                     [ATA, AAC, GAC, ACA, AAA, AAT]                  NaN
# 22                     [CTT, GTC, TTA, TCA, ATG, TAA]                  yes
# 23                [GTT, TTT, ACA, TTG, ATA, AGA, CAA]                  NaN
# 24                     [GTT, AAG, AAA, AGA, CGC, TTA]                  NaN
# 25  [TCA, CGC, TTA, ACT, TTT, GAT, CTG, ATA, ATT, ...                  NaN
#
#    possible frameshift wt_gene_translated mutant allele_translated
# 0                  NaN            NLRKTNV                  NLRKTNV
# 1                  NaN             YNGISP                   YNGMSP
# 2                  NaN             GGGEIP                   GGGDIP
# 3                  NaN             ELY***                   ELYK**
# 4                  NaN            ELY***V                  ELY***V
# 5                  NaN             TLNKFI                   TLNTFI
# 6                  NaN            FSKPEFK                  FSKPEFK
# 7                  NaN             F*ILAW                   F*IRAW
# 8                  NaN             SSSEQL                   SSSKQL
# 9                  yes            ENPPN*S                  ENPPN*S
# 10                 yes             PATMDS                   PATNGL
# 11                 yes              SESIV                   SESISC
# 12                 yes             FEK*PL                   FEKIAP
# 13                 yes             LKRQKY                 LKRRDKNT
# 14                 yes             KQE*HV                  KQESNML
# 15                 yes             ITCYSC                  ITCYSLA
# 16                 yes             TSFCFF                   TSFCFF
# 17                 yes             KKKQKL                   KKKQKL
# 18                 yes             D*KNKK                  D*KKHKK
# 19                 yes             VFLFF*                  VFLCFF*
# 20                 yes             YT*IF*                   YT*NLL
# 21                 yes             INDQKI                   INDTKN
# 22                 yes             LVL*CK                   LVLSM*
# 23                 yes            VFTL*DK                  VFTLIRQ
# 24                 NaN            VKKSTLK                   VKKRRL
# 25                 NaN             SRLTFD              SRLTFDLIIFD

# %%
#show for entries where ID doesnt start wiht SPNCRNA
frameshift_df[frameshift_df['ID'].str.startswith('SPNCRNA') == False]
# Out:
#     position            ID          Parent object chromosome    start  \
# 0    3364859  SPAC26A3.13c  SPAC26A3.13c.1    CDS          I  3361547
# 6    2227937  SPCC1919.10c  SPCC1919.10c.1    CDS        III  2225048
# 8    2228740  SPCC1919.10c  SPCC1919.10c.1    CDS        III  2225048
# 24   2291604   SPCC965.05c   SPCC965.05c.1    CDS        III  2291004
#
#         end strand detail     beta  ...                      allele_1  \
# 0   3365548      -   exon  0.54646  ...                             C
# 6   2229460      -   exon  0.55837  ...                             T
# 8   2229460      -   exon  0.55837  ...                             C
# 24  2291981      -   exon  0.40160  ...  ATGGGAGTTTCGTAGACAATTCTTTTCG
#
#    allele_2  reference_seq  reference_seq_  \
# 0         T    CTT |C| TGT         CTTCTGT
# 6         G    CGG |T| CTT         CGGTCTT
# 8         T    AGC |C| TTG         AGCCTTG
# 24        G    TTC |G| TGC         TTCGTGC
#
#                                      wt_gene  \
# 0   [CTG, AGG, AAG, ACA, AAT, GTT, TCG, AGA]
# 6   [TCC, AAG, CCA, GAA, TTC, AAA, AAT, AGT]
# 8        [TCC, TCG, GAA, CAA, CTT, GAA, AAG]
# 24  [AAG, AAA, AGC, ACG, CTT, AAA, AAG, AAG]
#
#                                mutant allele stop_codon_predicted  \
# 0   [CTG, AGG, AAA, ACA, AAT, GTT, TCG, AGA]                  NaN
# 6   [TCC, AAG, CCC, GAA, TTC, AAA, AAT, AGT]                  NaN
# 8        [TCC, TCG, AAA, CAA, CTT, GAA, AAG]                  NaN
# 24       [AAG, AAA, AGA, CGC, TTA, AAA, AGA]                  NaN
#
#    possible frameshift wt_gene_translated mutant allele_translated
# 0                  NaN           LRKTNVSR                 LRKTNVSR
# 6                  NaN           SKPEFKNS                 SKPEFKNS
# 8                  NaN            SSEQLEK                  SSKQLEK
# 24                 NaN           KKSTLKKK                  KKRRLKR
#
# [4 rows x 27 columns]
